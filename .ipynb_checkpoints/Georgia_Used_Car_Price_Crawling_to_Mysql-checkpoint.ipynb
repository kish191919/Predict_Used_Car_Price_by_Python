# %%
import numpy as np
import pandas as pd
import pickle

import bs4 as bs
import urllib.request
import json
from bs4 import BeautifulSoup
import requests
import re
from collections import Counter

import MySQLdb, pickle
from sqlalchemy import create_engine

# %%
df = pd.DataFrame(columns = ['year', 'title','brand','model','miles','photos','video','exterior_color','interior_color','transmission','drivetrain','star','review_no','vendor','price'])

for page in range(1,51):
    url = 'https://www.cars.com/for-sale/searchresults.action/?page='+str(page)+'&perPage=100&rd=99999&searchSource=PAGINATION&showMore=true&sort=relevance&stkTypId=28881&zc=31216'

    sauce = urllib.request.urlopen(url).read()
    soup = bs.BeautifulSoup(sauce, 'lxml')

    specificSoup = soup.find_all('div', class_='listing-row__details')

    

    for div in specificSoup:
        name_index = div.find('h2', {'class' :'cui-delta listing-row__title'}).text
        name = name_index.split("\n")[1]

    
        year_index = re.findall('[0-9]{4}',name)[0:1]
        year = year_index[0]

        title_index = name.split(" ")[29:34]
        title = " ".join(title_index)

        brand = title.split(" ")[0]
        
        try:
            model = title.split(" ")[1]
        except:
            model = brand

        mile_index = div.find('span', {'class' : 'listing-row__mileage'}).text
        miles = mile_index.split("\n")[0]
        regex = re.compile("\d+")
        miles = regex.findall(miles) 
        miles = ''.join(miles)

        vendor_index =div.find('div',{'class' : 'listing-row__dealer-name listing-row__dealer-name-mobile'}).text
        vendor_group = vendor_index.split(' ')[0:4]

        vendor = ''
        for i in vendor_group:
            if i == '':continue
            elif re.findall('\n', i): vendor += re.sub('\n', '', i)
            else: vendor += " "+ i +" "

        photos_index = div.find('div', {'class' : 'media-count shadowed'}).text
        photos = re.findall('[0-9]{1,3}',photos_index.split("\n")[1])[0]

        video_index = div.find('div', {'class' : 'media-count shadowed'}).text
        try: 
            video = re.findall('[0-9]{1,3}',photos_index.split("\n")[2])[0]
        except:
            video = 0

        exterior_color = div.find('ul', {'class' : 'listing-row__meta'}).text
        try:
            exterior_color = re.sub('\n', ' ',exterior_color).split(" ")[4]
        except:
            exterior_color = 'black'
        
        interior_color = div.find('ul', {'class' : 'listing-row__meta'})
        try:
            interior_color = list(interior_color)[3].text.split(" ")[3:5]
        except:
            interior_color = "black"
        interior_color = " ".join(interior_color)
        interior_color = re.sub('/' , ' ' ,interior_color)

        transmission = div.find('ul', {'class' : 'listing-row__meta'})
        try:
            transmission = list(transmission)[5].text.split(" ")[2]
        except:
            transmission = "6-speed"
            

        drivetrain = div.find('ul', {'class' : 'listing-row__meta'})
        try:
            drivetrain = list(drivetrain)[7].text.split(" ")[2:5]
        except: 
            drivetrain = 'fwd'
        drivetrain = " ".join(drivetrain).lower()
        if drivetrain == 'rear wheel drive':
            drivetrain = 'rwd'
        elif drivetrain == 'front wheel drive':
            drivetrain = 'fwd'
        elif drivetrain == 'all wheel drive':
            drivetrain = '4wd'


        if div.find('div',{'class' : 'dealer-rating-stars'}) == None:
            star = 0
        else:
            star_index =div.find('div',{'class' : 'dealer-rating-stars'}).text
            star = star_index.split(" ")[36]
            regex = re.compile("\d")
            star = regex.findall(star)[0] 

        
        if div.find('span',{'class' : 'listing-row__review-number'}) == None:
            review_no = 0
        else:
            review_index =div.find('span',{'class' : 'listing-row__review-number'}).text
            review_no = re.sub('\n', '',review_index.split(" ")[1])

        if div.find('span', {'class' : 'listing-row__price'}) == None:
            price = 0
        else:
            price_index = div.find('span', {'class' : 'listing-row__price'}).text
            price = price_index.split("\n")[1]
            regex = re.compile("\d")
            price = ''.join(regex.findall(price))
            price



        data = { 
                'year' : year,
                'title' : title.lower(),
                'brand': brand.lower(),
                'model': model.lower(),
                'miles' : miles,
                'photos': photos,
                'video' : video,
                'exterior_color' : exterior_color.lower(),
                'interior_color' : interior_color.lower(),
                'transmission' : transmission.lower(),
                'drivetrain' : drivetrain.lower(),
                'star': star,
                'review_no' : review_no,

                'vendor' : vendor.lower(),
                'price': price,
                    }


        df.loc[len(df)] = data
        
df['transmission'] = df['transmission'].apply(lambda x: '6-speed' if x == 'automatic' or x == '6' else x)
df['transmission'] = df['transmission'].apply(lambda x: '8-speed' if x == '8' else x)
df['transmission'] = df['transmission'].apply(lambda x: '5-speed' if x == '5' else x)   
df['transmission'] = df['transmission'].apply(lambda x: '5-speed' if x == '5' else x)   
df['transmission'] = df['transmission'].apply(lambda x: 'x-speed' if x != '1-speed' and x != '2-speed' and x != '3-speed' and \
                                              x != '4-speed' and x != '5-speed' and x != '6-speed' and x != '7-speed' and x != '7-speed' and\
                                              x != '8-speed' and x != '9-speed' and x != '10-speed' \
                                              else x)
df['drivetrain'] = df['drivetrain'].apply(lambda x: '4wd' if x == 'four wheel drive' or x == '4wd' or x=='4x4'or x=='awd'else x)
df['drivetrain'] = df['drivetrain'].apply(lambda x: 'fwd' if x == '2wd' or x=='f w d' else x)
df['drivetrain'] = df['drivetrain'].apply(lambda x: '4wd' if x != 'fwd' and  x!='rwd' and x!='4wd' else x)

df
# Out:
#       year                               title          brand       model  \
# 0     2003                 mazda tribute lx v6          mazda     tribute
# 1     2016               subaru crosstrek 2.0i         subaru   crosstrek
# 2     2018                   ford f-150 raptor           ford       f-150
# 3     2015                          lexus rc f          lexus          rc
# 4     2014                 mercedes-benz s 550  mercedes-benz           s
# 5     2016      mercedes-benz gl 63 amg 4matic  mercedes-benz          gl
# 6     2017           infiniti q50 3.0t premium       infiniti         q50
# 7     2016               jeep compass latitude           jeep     compass
# 8     2008                      subaru outback         subaru     outback
# 9     2016                  tesla model x p90d          tesla       model
# 10    2004                          bmw 645 ci            bmw         645
# 11    2010                       toyota tundra         toyota      tundra
# 12    2016              chevrolet corvette z06      chevrolet    corvette
# 13    2016                     lexus gs f base          lexus          gs
# 14    2012                         ram 1500 st            ram        1500
# 15    2008                     honda cr-v ex-l          honda        cr-v
# 16    2014                maserati ghibli s q4       maserati      ghibli
# 17    2014        mercedes-benz cla 250 4matic  mercedes-benz         cla
# 18    2006         rolls-royce phantom vi base    rolls-royce     phantom
# 19    2015                 mercedes-benz c 300  mercedes-benz           c
# 20    2006                           bmw 325 i            bmw         325
# 21    2004                   porsche 911 targa        porsche         911
# 22    2014                         audi r8 4.2           audi          r8
# 23    2012                       kia optima ex            kia      optima
# 24    2014                mercedes-benz slk250  mercedes-benz      slk250
# 25    2016                         bmw m4 base            bmw          m4
# 26    2013                   lexus lx 570 base          lexus          lx
# 27    2012               hyundai veloster base        hyundai    veloster
# 28    2007               pontiac grand prix gt        pontiac       grand
# 29    2015          mercedes-benz s 550 4matic  mercedes-benz           s
# ...    ...                                 ...            ...         ...
# 4970  2018                chevrolet camaro 1ss      chevrolet      camaro
# 4971  2014      volkswagen passat 2.0l tdi dsg     volkswagen      passat
# 4972  2013                         bmw m3 base            bmw          m3
# 4973  2016                jaguar xj xj r-sport         jaguar          xj
# 4974  2010                mazda mazda3 i sport          mazda      mazda3
# 4975  2015                bmw alpina b6 xdrive            bmw      alpina
# 4976  2011                    porsche panamera        porsche    panamera
# 4977  2017                         audi r8 5.2           audi          r8
# 4978  2015                 mercedes-benz s 600  mercedes-benz           s
# 4979  2013                mercedes-benz cls550  mercedes-benz      cls550
# 4980  2015           maserati ghibli 4dr sedan       maserati      ghibli
# 4981  2011                         bmw m3 base            bmw          m3
# 4982  2015                    nissan sentra sl         nissan      sentra
# 4983  2006                    porsche cayman s        porsche      cayman
# 4984  2016                         lincoln mkt        lincoln         mkt
# 4985  2017           audi s3 2.0t premium plus           audi          s3
# 4986  2017               lamborghini aventador    lamborghini   aventador
# 4987  2000                 porsche 911 carrera        porsche         911
# 4988  2015                   infiniti q40 base       infiniti         q40
# 4989  2015                      jaguar xj base         jaguar          xj
# 4990  2015           toyota highlander le plus         toyota  highlander
# 4991  2015         mercedes-benz ml 350 4matic  mercedes-benz          ml
# 4992  2017   mercedes-benz gle 350 base 4matic  mercedes-benz         gle
# 4993  2017                  infiniti qx70 base       infiniti        qx70
# 4994  2016  toyota highlander limited platinum         toyota  highlander
# 4995  2015      volkswagen passat 2.0l tdi dsg     volkswagen      passat
# 4996  2015                   toyota corolla le         toyota     corolla
# 4997  2015                      jaguar xj base         jaguar          xj
# 4998  2015                         kia soul ev            kia        soul
# 4999  2016                        lexus rx 350          lexus          rx
#
#        miles photos video exterior_color      interior_color transmission  \
# 0     118205     21     1         silver                gray      4-speed
# 1      26525     23     1         desert               black      5-speed
# 2       2330     32     1           race               black     10-speed
# 3      27080     23     1          black                 red      8-speed
# 4     121078     32     1      palladium          silk beige      7-speed
# 5      17582     32     1          black        auburn brown      7-speed
# 6      31736     26     1       platinum               black      7-speed
# 7      46644     25     1        granite          dark slate      6-speed
# 8     199532     29     1           gray                gray      6-speed
# 9      17342     32     1          black               black      1-speed
# 10    106334     31     1         silver         creme beige      6-speed
# 11    212000     23     1          white                 tan      6-speed
# 12     11124     28     1          beach          brownstone      8-speed
# 13     30646     32     1         nebula                 red      8-speed
# 14    159272     20     1           true   dark slate medium      6-speed
# 15     93043     32     1          black                gray      5-speed
# 16     36037     31     1          black               black      8-speed
# 17     40784     32     1          white               black      7-speed
# 18     23050     32     1           gray                 tan      6-speed
# 19     35286     32     1         silver               black      7-speed
# 20    112676     32     1         silver                gray      6-speed
# 21     49943     32     1         basalt       brown leather      6-speed
# 22     16864     23     1       metallic               black      7-speed
# 23     74974     27     1         silver                gray      6-speed
# 24     10571     21     1          black               black      7-speed
# 25     28407     28     1          black          opal white      7-speed
# 26    101791     32     1          black               black      6-speed
# 27     74824     21     1          ultra               black      6-speed
# 28    110422     20     1          ivory            cashmere      4-speed
# 29     25016     32     1        iridium               black      7-speed
# ...      ...    ...   ...            ...                 ...          ...
# 4970    2240     21     1          hyper           jet black      6-speed
# 4971  123272     26     0          opera             beige        6-speed
# 4972   32039     31     1         alpine               black      7-speed
# 4973   14653     30     1       ultimate                 jet      8-speed
# 4974  184511     24     1          black               black      5-speed
# 4975   41042     32     1         citrin               black      8-speed
# 4976   96479     30     1          black  automatic w manual      x-speed
# 4977    5522     26     1          vegas            graphite      7-speed
# 4978   25434     32     1          black               black      7-speed
# 4979   68123     26     1        diamond               black      7-speed
# 4980   16894     23     1         bianco               brown      8-speed
# 4981   92421     32     1          black                 red      6-speed
# 4982   43097     23     1       amethyst               beige      6-speed
# 4983   59710     32     0       midnight          stone grey      6-speed
# 4984   40922     23     1          black                 n a      6-speed
# 4985    6446     24     1        glacier               black      6-speed
# 4986   11023     43     1           nero            nero ade      7-speed
# 4987   98600     22     1           gray                          x-speed
# 4988   31215     32     1          black               beige      7-speed
# 4989   37580     32     1           dark            oyster        8-speed
# 4990   29928     32     1         silver                gray      6-speed
# 4991   52457     32     1         silver               black      7-speed
# 4992    6389     32     1            off               beige      7-speed
# 4993    3286     32     1          black               black      7-speed
# 4994   35067     32     1          white                gray      6-speed
# 4995   19872     32     1          black               beige      6-speed
# 4996   28695     32     1            red                 tan      6-speed
# 4997   37580     32     1           dark            oyster        8-speed
# 4998   30041     32     1          white                gray      1-speed
# 4999   19254     32     1           dark               brown      8-speed
#
#      drivetrain star review_no                             vendor   price
# 0           fwd    5        43                   1st choice autos    3750
# 1           4wd    5        43                   1st choice autos   17999
# 2           4wd    5       244              gilbert &  baugh ford   53900
# 3           rwd    5         6             carmax south boulevard   43998
# 4           rwd    5       939                        hendrickbmw   32991
# 5           4wd    5        19            global motorsports inc.   79895
# 6           rwd    5        18     hertz car  sales winston-salem   19998
# 7           fwd    5        90         hertz car  sales  orlando    11488
# 8           4wd    5        16                        sharpmotors    3950
# 9           4wd    5        96                 bayshoreautomotive  104890
# 10          rwd    5        77                     rdu auto sales    9995
# 11          4wd    5         6               motortime auto sales   11995
# 12          rwd    4        86                     skylineimports   67900
# 13          rwd    5       117                 motorcarslouisiana   56900
# 14          rwd    5        10                      n &  n  auto    10935
# 15          4wd    5         7                 auto mart  of ohio    8995
# 16          4wd    5        15                      creeksideauto   33495
# 17          4wd    5        23                  jumbo luxury cars   16990
# 18          rwd    5        23                  jumbo luxury cars  105000
# 19          4wd    5        23                  jumbo luxury cars   23990
# 20          rwd    5         8                   pride auto sales    5895
# 21          rwd    5        54               chantilly auto sales   29995
# 22          4wd    4        95        action pre-owned automotive   88999
# 23          fwd    5        24                   mini of sterling    9922
# 24          rwd    5         8                       carmaxdulles   28998
# 25          rwd    5        65           luxury sports  & imports   53950
# 26          4wd    5        31          virginia auto  trader co.   34995
# 27          fwd    5        31          virginia auto  trader co.    7995
# 28          fwd    5        45     cherner brothers  auto brokers    4293
# 29          4wd    5        60        mercedes-benz of pittsburgh   58399
# ...         ...  ...       ...                                ...     ...
# 4970        rwd    5        67                      concordnissan   34990
# 4971        fwd    4      1089                 luther westside vw   10875
# 4972        rwd    4        34               bmw north scottsdale   39517
# 4973        rwd    5        50                    onyxmotorsports   47988
# 4974        fwd    5         7                          murdockgm    3975
# 4975        4wd    5        19                           vipautos   61499
# 4976        fwd    4       346                    siry auto group   27999
# 4977        4wd    1         4         maserati of  anaheim hills  156796
# 4978        rwd    5        12                        eurocarinc.   89888
# 4979        rwd    4       591                   house of imports   26500
# 4980        rwd    5        54                     jem motor corp   36300
# 4981        rwd    0         0             loyal signature motors   24995
# 4982        fwd    5        15             shingle springs subaru   14188
# 4983        rwd    5         7                    luxurymotorcars   26900
# 4984        4wd    0         0          carmax capitol expressway   21998
# 4985        4wd    4        69        san francisco  audi  mazda    42000
# 4986        4wd    3         9  british motor  car  distributors   395900
# 4987        fwd    5        19          full throttle  auto sales   23995
# 4988        rwd    4        44        carvana raleigh  (as  soon    19400
# 4989        4wd    4        42        carvana chicago  (as  soon    33400
# 4990        4wd    4        65      carvana nashville  (as  soon    26800
# 4991        4wd    4        43   carvana indianapolis  (as  soon    27700
# 4992        4wd    4        42     carvana pittsburgh  (as  soon    52400
# 4993        4wd    4        42           carvana st.  louis  (as    37200
# 4994        4wd    4        41             carvana new  york  #1    36200
# 4995        fwd    4        43   carvana indianapolis  (as  soon    19000
# 4996        fwd    4        42          carvana hartford  &  new    12900
# 4997        4wd    4        41         carvana tucson  (as  soon    33400
# 4998        fwd    4        44        carvana raleigh  (as  soon    15000
# 4999        4wd    4        46        carvana houston  (as  soon    39100
#
# [5000 rows x 15 columns]

# %%
df = df[df["price"] != ""]
df = df[df["brand"] != ""]

# %%
df["year"] = df["year"].astype('int')
df["miles"] = df["miles"].astype('int')
df["photos"] = df["photos"].astype('int')
df["video"] = df["video"].astype('int')
df["star"] = df["star"].astype('int')
df["review_no"] = df["review_no"].astype('int')
df["price"] = df["price"].astype('int')

# %%
pw = pickle.load(open('./Data/pw.plk','rb'))

# %%
# write local car_info
engine = create_engine("mysql+mysqldb://root:" + pw + "@127.0.0.1/used_car")
df.to_sql(name="used_car", con=engine, if_exists='replace')
