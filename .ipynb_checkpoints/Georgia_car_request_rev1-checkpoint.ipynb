# %%
import bs4 as bs
import urllib.request
import json
from xlwt import Workbook
import locale
from bs4 import BeautifulSoup
import requests
import re

# %%
url = 'https://www.cars.com/for-sale/searchresults.action/?page=1&perPage=100&rd=99999&searchSource=PAGINATION&showMore=true&sort=relevance&stkTypId=28881&zc=31216'

# %%
sauce = urllib.request.urlopen(url).read()
soup = bs.BeautifulSoup(sauce, 'lxml')

# %%
specificSoup = soup.find_all('div', class_='listing-row__details')

# %%
name_index = div.find('h2', {'class' :'cui-delta listing-row__title'}).text
name = name_index.split("\n")[1]
name
# Out:
# '                            2016 Toyota Corolla L'

# %%
df = pd.DataFrame(columns = ['year', 'title','company','subname','mile','photos','video','exterior_color','interior_color','transmission','drivetrain','star','review_no','vendor','price'])

for div in specificSoup:
    name_index = div.find('h2', {'class' :'cui-delta listing-row__title'}).text
    name = name_index.split("\n")[1]

    
    year_index = re.findall('[0-9]{4}',name)[0:1]
    year = year_index[0]

    title_index = name.split(" ")[29:34]
    title = " ".join(title_index)
    
    company = title.split(" ")[0]
    subname = title.split(" ")[1]
    
    mile_index = div.find('span', {'class' : 'listing-row__mileage'}).text
    mile = mile_index.split("\n")[0]
    
    vendor_index =div.find('div',{'class' : 'listing-row__dealer-name listing-row__dealer-name-mobile'}).text
    vendor_group = vendor_index.split(' ')[0:4]
    
    vendor = ''
    for i in vendor_group:
        if i == '':continue
        elif re.findall('\n', i): vendor += re.sub('\n', '', i)
        else: vendor += " "+ i +" "
        
    photos_index = div.find('div', {'class' : 'media-count shadowed'}).text
    photos = re.findall('[0-9]{1,3}',photos_index.split("\n")[1])[0]
  
    video_index = div.find('div', {'class' : 'media-count shadowed'}).text
    video = re.findall('[0-9]{1,3}',photos_index.split("\n")[2])
    
    exterior_color = div.find('ul', {'class' : 'listing-row__meta'}).text
    exterior_color = re.sub('\n', ' ',exterior_color).split(" ")[4]
    
    interior_color = div.find('ul', {'class' : 'listing-row__meta'})
    interior_color = list(interior_color)[3].text.split(" ")[3:5]
    interior_color = " ".join(interior_color)
    interior_color = re.sub('/' , ' ' ,interior_color)
    
    transmission = div.find('ul', {'class' : 'listing-row__meta'})
    transmission = list(transmission)[5].text.split(" ")[2]
    
    drivetrain = div.find('ul', {'class' : 'listing-row__meta'})
    drivetrain = list(drivetrain)[7].text.split(" ")[2:5]
    drivetrain = " ".join(drivetrain).lower()
    if drivetrain == 'rear wheel drive':
        drivetrain = 'rwd'
    elif drivetrain == 'front wheel drive':
        drivetrain = 'fwd'
    elif drivetrain == 'all wheel drive':
        drivetrain = '4wd'
    elif drivetrain == 'four wheel drive':
        drivetrain == '4wd'

    star_index =div.find('div',{'class' : 'dealer-rating-stars'}).text
    star = star_index.split(" ")[36]

    review_index =div.find('span',{'class' : 'listing-row__review-number'}).text
    review_no = re.sub('\n', '',review_index.split(" ")[1])

    price_index = div.find('span', {'class' : 'listing-row__price'}).text
    price = price_index.split("\n")[1]

    
    
    data = { 
            'year' : year,
            'title' : title.lower(),
            'company': company.lower(),
            'subname': subname.lower(),
            'mile' : mile,
            'photos': photos,
            'video' : video,
            'exterior_color' : exterior_color.lower(),
            'interior_color' : interior_color.lower(),
            'transmission' : transmission.lower(),
            'drivetrain' : drivetrain,
            'star': star,
            'review_no' : review_no,
          
            'vendor' : vendor.lower(),
            'price': price,
                }


    df.loc[len(df)] = data
    

df
# Out:
#     year                              title        company     subname  \
# 0   2016                   toyota corolla l         toyota     corolla
# 1   2014          mercedes-benz c 250 sport  mercedes-benz           c
# 2   2016          dodge challenger r/t plus          dodge  challenger
# 3   2005    porsche 911 carrera s cabriolet        porsche         911
# 4   2015                          bmw 228 i            bmw         228
# 5   2010                mercedes-benz e 550  mercedes-benz           e
# 6   2014                          bmw 335 i            bmw         335
# 7   2016  toyota camry se w/special edition         toyota       camry
# 8   2018              dodge charger r/t 392          dodge     charger
# 9   2007       chevrolet avalanche lt w/3lt      chevrolet   avalanche
# 10  2013                   bmw x5 xdrive35i            bmw          x5
# 11  2009                      pontiac g8 gt        pontiac          g8
# 12  2016                 tesla model x p90d          tesla       model
# 13  2013   hyundai genesis coupe 3.8 r-spec        hyundai     genesis
# 14  2011                 toyota 4runner sr5         toyota     4runner
# 15  2007                  infiniti m35 base       infiniti         m35
# 16  2007           toyota tacoma access cab         toyota      tacoma
# 17  2016               mclaren 675lt spider        mclaren       675lt
# 18  2017                   bentley bentayga        bentley    bentayga
# 19  2009               subaru forester 2.5x         subaru    forester
# 20  2010                     honda civic lx          honda       civic
# 21  2010                  toyota yaris base         toyota       yaris
# 22  2013                    ferrari ff base        ferrari          ff
# 23  2016                  tesla model x 90d          tesla       model
# 24  2014         mercedes-benz s 550 4matic  mercedes-benz           s
# 25  2011                   bmw 328 i xdrive            bmw         328
# 26  2004                  porsche 911 targa        porsche         911
# 27  2014              lexus ct 200h premium          lexus          ct
# 28  2014               mercedes-benz slk250  mercedes-benz      slk250
# 29  2015               porsche panamera gts        porsche    panamera
# ..   ...                                ...            ...         ...
# 70  2010                     honda civic lx          honda       civic
# 71  2017                  toyota tacoma sr5         toyota      tacoma
# 72  2014                 jeep compass sport           jeep     compass
# 73  2015    chevrolet corvette stingray z51      chevrolet    corvette
# 74  2001             chevrolet corvette z06      chevrolet    corvette
# 75  2010             nissan frontier pro-4x         nissan    frontier
# 76  2009                    kia sportage lx            kia    sportage
# 77  2011             mazda mazda3 i touring          mazda      mazda3
# 78  2014             toyota tundra platinum         toyota      tundra
# 79  2011                   mini cooper base           mini      cooper
# 80  2015              gmc yukon xl 1500 sle            gmc       yukon
# 81  2004                 mercedes-benz 5.0l  mercedes-benz        5.0l
# 82  2006                        bmw x3 3.0i            bmw          x3
# 83  2013                   bmw x5 xdrive35i            bmw          x5
# 84  2015               infiniti q50 premium       infiniti         q50
# 85  2017               jeep compass limited           jeep     compass
# 86  2017         mercedes-benz amg cls 63 s  mercedes-benz         amg
# 87  2015                mercedes-benz s 550  mercedes-benz           s
# 88  2013         dodge challenger srt8 core          dodge  challenger
# 87   17,900 mi.     32   [1]      magnetite          saddle nappa
# 88   33,176 mi.     24   [1]          black                 black
# 89   12,680 mi.     31   [1]            jet         black leather
# 90   27,211 mi.     50   [1]        crystal                 black
# 91    8,742 mi.     54   [1]          black                 black
# 92   17,811 mi.     25   [1]          white                 black
# 93   43,178 mi.     30   [1]          space                 black
# 94    9,791 mi.     32   [1]        balloon              nero ade
# 95  132,674 mi.     23   [1]      sandstone                 tan
# 96   10,723 mi.     32   [1]           fuji               ebony
# 97   43,194 mi.     27   [1]         silver                  gray
# 98    9,711 mi.     32   [1]         bianco              nero ade
# 99   63,940 mi.     24   [1]          pearl                  gray
#
#     transmission        drivetrain   star review_no  \
# 0        4-speed               fwd    (5)        43
# 1        7-speed               rwd    (5)        41
# 2        6-speed               rwd    (5)        10
# 3        6-speed               rwd    (5)        11
# 4        8-speed               rwd    (5)         6
# 5        7-speed               rwd    (5)        26
# 6        8-speed               rwd    (5)        26
# 7        6-speed               fwd    (5)         6
# 8        8-speed               rwd    (5)        46
# 9        4-speed  four wheel drive    (5)        21
# 10       8-speed               awd    (5)         7
# 11       6-speed               rwd    (5)         8
# 12       1-speed               awd    (5)        96
# 13       6-speed               rwd    (5)        41
# 14       5-speed               rwd    (5)         9
# 15       5-speed               rwd    (5)        23
# 16       5-speed               4wd    (5)        26
# 17       7-speed               rwd    (5)         6
# 18       8-speed               awd    (5)        34
# 19       4-speed               awd    (5)        25
# 20       5-speed               fwd    (5)         7
# 21       4-speed               fwd    (5)         7
# 22       7-speed               awd    (5)        23
# 23       1-speed               awd    (5)        23
# 24       7-speed               awd    (5)        23
# 25       6-speed               4wd    (5)         7
# 26             6               rwd    (5)        54
# 27  continuously               fwd    (5)        21
# 28       7-speed               rwd    (5)         8
# 29       7-speed               awd    (5)        31
# ..           ...               ...    ...       ...
# 70       5-speed               fwd    (5)        56
# 71       6-speed               4wd    (5)         8
# 72     automatic               4wd    (5)        45
# 73       7-speed               rwd    (5)         7
# 74       6-speed               rwd    (5)        24
# 75       5-speed               4wd    (5)        24
# 76       4-speed               fwd    (5)        52
# 77       5-speed               fwd    (5)        52
# 78     automatic               4x4    (5)        10
# 79       6-speed               fwd    (5)         8
# 80       6-speed               4wd    (5)        33
# 81       5-speed               4wd    (5)         9
# 82       5-speed               awd    (5)        13
# 83       8-speed               awd    (5)        37
# 84       7-speed               awd    (5)         9
# 85       9-speed  four wheel drive    (5)        34
# 86       7-speed               awd  (4.9)       194
# 87     automatic               awd    (5)        16
# 88       6-speed               rwd    (5)        38
# 89             6               rwd    (5)         8
# 90     automatic               fwd    (5)        32
# 91       9-speed               awd    (5)        45
# 92       7-speed               fwd    (5)        15
# 93       6-speed               rwd    (5)        20
# 94       7-speed               awd    (5)        12
# 95       4-speed               rwd    (5)        20
# 96       9-speed               4wd    (5)         9
# 97       6-speed               4wd    (5)        46
# 98       7-speed               awd    (5)        32
# 99       6-speed               fwd    (5)        16
#
#                                     vendor  \
# 0                         1st choice autos
# 1                  vaden nissan statesboro
# 2                 exclusive auto wholesale
# 3                       united imports inc
# 4                   carmax south boulevard
# 5                      inetwork auto group
# 6                      inetwork auto group
# 7                      ultimate motor cars
# 8                     carolina auto direct
# 9                        minton motor cars
# 10                     cars of  tampa, inc
# 11                   ez choice  auto sales
# 12                      bayshoreautomotive
# 13                        wolfchasehyundai
# 14             wholesale auto  group, inc.
# 15                     joseph leasing, llc
# 16                  don wood  ford lincoln
# 17                  lamborghini palm beach
# 18                excell auto  group, inc.
# 19                            widerangellc
# 20                      auto mart  of ohio
# 21                      auto mart  of ohio
# 22                       jumbo luxury cars
# 23                       jumbo luxury cars
# 24                       jumbo luxury cars
# 25                    rock's auto exchange
# 26                    chantilly auto sales
# 27                         altech cars ltd
# 28                            carmaxdulles
# 29                   porsche tysons corner
# ..                                     ...
# 70                       luxury motor club
# 71                    toyota of massapequa
# 72                   certifiedheadquarters
# 73                       jackie cooper bmw
# 74                         r and  r  auto
# 75                         r and  r  auto
# 76                            ful-lineauto
# 77                            ful-lineauto
# 78  bluebonnet chrysler  dodge  certified
# 79                        pat's auto sales
# 80                             sandymotors
# 81                international auto sales
# 82                        will dicker auto
# 83                        porsche st. paul
# 84                 marx motors  on  first
# 85             credit union  auto  buying
# 86                       land rover denver
# 87                             worldmotors
# 88                             fiuzamotors
# 89               autobahn west enterprises
# 90                         lexus san diego
# 91                      mini of  san diego
# 92                       randys auto sales
# 93                    johnny's motors inc.
# 94                             eurocarinc.
# 95                    johnny's motors inc.
# 96                             fresnolexus
# 97                        qualitypre-owned
# 98                             catsexotics
# 99                     autos only lynnwood
#
#                                        price
# 0                                    $11,999
# 1                                    $17,900
# 2                                    $23,997
# 3                                    $30,990
# 4                                    $19,998
# 5                                    $18,549
# 6                                    $23,911
# 7                                    $17,418
# 8                                    $35,999
# 9                                    $17,999
# 10                                   $22,995
# 11                                   $14,999
# 12                                  $104,890
# 13                                   $14,500
# 14                                   $18,777
# 15                                    $5,988
# 16                                    $8,000
# 17                                  $339,951
# 18                                  $195,000
# 19                                    $6,695
# 20                                    $6,570
# 21                                    $5,310
# 22                                  $139,990
# 23                                   $96,990
# 24                                   $42,990
# 25                                   $12,000
# 26                                   $29,995
# 27                                   $16,995
# 28                                   $28,998
# 29                                   $74,595
# ..                                       ...
# 70                                    $7,250
# 71                                   $28,991
# 72                                   $11,988
# 73                                   $39,940
# 74                                   $23,999
# 75                                   $14,499
# 76                                    $7,495
# 77                                    $5,495
# 78                                   $23,991
# 79                                    $7,995
# 80                                   $27,900
# 81                                    $9,987
# 82                                    $7,495
# 83                                   $24,977
# 84                                   $19,999
# 85                                   $22,988
# 86                                   $94,995
# 87                                   $53,995
# 88                                   $23,998
# 89                                   $23,889
# 90                                   $16,993
# 91                                   $52,995
# 92                                   $24,999
# 93                                   $11,999
# 94                                  $279,777
# 95                                    $5,999
# 96                                   $32,900
# 97                                   $29,875
# 98                                  $269,000
# 99                                    $8,998
#
# [100 rows x 15 columns]
